# %%
import pandas as pd
import matplotlib.pyplot as plt
from scipy.stats import linregress

# %%
df = pd.read_csv('epa-sea-level.csv')
df.head()
# Out:
#    Year  CSIRO Adjusted Sea Level  Lower Error Bound  Upper Error Bound
# 0  1880                  0.000000          -0.952756           0.952756  \
# 1  1881                  0.220472          -0.732283           1.173228
# 2  1882                 -0.440945          -1.346457           0.464567
# 3  1883                 -0.232283          -1.129921           0.665354
# 4  1884                  0.590551          -0.283465           1.464567
#
#    NOAA Adjusted Sea Level
# 0                      NaN
# 1                      NaN
# 2                      NaN
# 3                      NaN
# 4                      NaN

# %%
plt.scatter(df['Year'],df['CSIRO Adjusted Sea Level'])

# %%
slope,intercept,r_value,p_value,std_err = linregress(df['Year'],df['CSIRO Adjusted Sea Level'])
# y = slope*x+intercept
x = [1850,2050]
y = [0,0]
for i in range(2):
    y[i] = slope*x[i]+intercept
y
# Out:
# [-2.433461545290413, 10.175455257136548]

# %%
plt.scatter(df['Year'],df['CSIRO Adjusted Sea Level'])
plt.plot(x,y,'r-')
plt.show()

# %%
new_df = df[df['Year']>=2000]

# %%
slope,intercept,r_value,p_value,std_err = linregress(new_df['Year'],new_df['CSIRO Adjusted Sea Level'])
# y = slope*x+intercept
x = [2000,2050]
y = [0,0]
for i in range(2):
    y[i] = slope*x[i]+intercept
y
# Out:
# [7.06107985777146, 15.382443524364874]

# %%
plt.scatter(new_df['Year'],new_df['CSIRO Adjusted Sea Level'])
plt.plot(x,y,'g-')
plt.show()
y[1]
# Out:
# 15.382443524364874
